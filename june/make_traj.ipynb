 15.485219801788912, 82), (8.439863458097973, 15.45476015829983, 83), (8.4673035585466, 15.425349347887146, 84), (8.493793412529403, 15.397000293973203, 85), (8.519321148755976, 15.369725919980343, 86), (8.54387489593592, 15.343539149330937, 87), (8.567442782778835, 15.318452905447312, 88), (8.590012937994324, 15.294480111751831, 89), (8.611573490291983, 15.271633691666835, 90), (8.632115711069376, 15.249923119883006, 91), (8.651643442475928, 15.229344076164335, 92), (8.670163669349026, 15.209888791543145, 93), (8.687683376526062, 15.191549497051762, 94), (8.704209548844421, 15.1743184237225, 95), (8.719749171141489, 15.158187802587685, 96), (8.734309228254663, 15.143149864679645, 97), (8.747896705021327, 15.129196841030701, 98), (8.760518586278867, 15.116320962673168, 99), (8.772181856864675 ...
#  list([[(5.100880101258238, 15.033991791567262, 26)], [(5.009601804571788, 19.460060656288977, 225)], [(9.405248613642408, 15.140560495742264, 674)]])
#  array([[15.79995   , 11.29986   ],
#         [15.79552059, 11.43939579]])]

# %%
meta_data, trajectories, destinations, obstacles = data
goal_positions = []
for u in destinations:
    goal_positions.append(u[0][:2])
print(goal_positions)

mean_v = []
for u in trajectories:
    first = u[0][:2]
    last = u[-1][:2]
    tau = u[-1][-1] - u[0][-1]
    first, last = np.array(first), np.array(last)
    v = (last - first) / tau
    v = v.tolist()
    mean_v.append(v)
print(mean_v)
mean_vx = [v[0] for v in mean_v]
mean_vy = [v[1] for v in mean_v]
print(mean_vx)
print(mean_vy)
# Out:
# [(5.100880101258238, 15.033991791567262), (5.009601804571788, 19.460060656288977), (9.405248613642408, 15.140560495742264)]
# [[0.024526806582397143, -0.05166357187609094], [-0.0002349180074003493, 0.001402893238077758], [0.06189186465326952, -0.07561801263280812]]
# [0.024526806582397143, -0.0002349180074003493, 0.06189186465326952]
# [-0.05166357187609094, 0.001402893238077758, -0.07561801263280812]

# %%
params_sfm = {
    "dt": 1/30,
    "A1": 2.1,
    "B": 0.3,
    "A2": 1,
    "tau": 0.5,
    "phi": 100,
    "c": 0.5
}
walls = np.array(obstacles)
walls_points = walls.tolist()
print(obstacles)
print(walls)
print(walls_points)
# Out:
# [[15.79995    11.29986   ]
#  [15.79552059 11.43939579]]
# [[15.79995    11.29986   ]
#  [15.79552059 11.43939579]]
# [[15.799949999999999, 11.29986], [15.79552058757197, 11.439395794440426]]

# %%
num_steps = max([u[-1][-1] for u in trajectories]) + 1
print(num_steps)

sfm = SocialForceModel(params_sfm, walls_points)
# Out:
# 675

# %%
#trajectoriesの中身の最初の1stepのx,y座標を取り出す
traj = []
for i in range(len(trajectories)):
    x = trajectories[i][0][0]
    y = trajectories[i][0][1]
    t = trajectories[i][0][-1]
    traj.append([x, y, t])
print(traj)
# Out:
# [[5.00277287492865, 15.240646079071626, 22], [5.058699668118461, 19.166855969530726, 16], [5.072818087913542, 20.433821380038832, 604]]

# %%
agents = run_SFM(traj, mean_v, num_steps, sfm, destinations)
print(agents)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 agents = run_SFM(traj, mean_v, num_steps, sfm, destinations)
#       2 print(agents)
#
# File ~/work/SFM/social-force-model-with-destination-choice/june/SFM.py:25, in run_SFM(trajectories, mean_v, num_step, sfm, dests)
#      22 agents = {}
#      23 for i in range(num_agent):
#      24     agents[i] = AgentSFM(no=i,
# ---> 25                       t0=trajectories[i][-1],
#      26                       r=0.2,
#      27                       v0=mean_v[i],
#      28                       loc=[np.array([np.nan, np.nan, np.nan])],
#      29                       vel=[np.array([np.nan, np.nan])],
#      30                       dest=[np.array([np.nan, np.nan])],
#      31                       )
#      33 t = 0
#      34 while t < num_step:  # until all pedestrians move to right
#
# IndexError: invalid index to scalar variable.
